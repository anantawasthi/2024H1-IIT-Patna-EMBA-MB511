# %% [markdown]
# ### **Variables and Data Types in Python**

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('6yrsX752CWk', width=960, height=540)

# %% [markdown]
# ### **Working with List**

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('9OeznAkyQz4', width=960, height=540)

# %% [markdown]
# ### **Working with Dictionary**

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('rZjhId0VkuY', width=960, height=540)

# %% [markdown]
# ### **Operators in Python**

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('Pm9FOpOwhlA', width=960, height=540)

# %% [markdown]
# ### **Loops in Python**

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('zFvoXxeoosI', width=960, height=540)

# %% [markdown]
# ### **Control Statements in Python**

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('nMEFZ6TvkDA', width=960, height=540)

# %% [markdown]
# ### **Functions in Python**

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('oSPMmeaiQ68', width=960, height=540)

# %% [markdown]
# ### **Libraries in Python**

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('LepMvJdr2-w', width=960, height=540)

# %% [markdown]
# ### **Building your own Package**

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('7GXaobCrBb4', width=960, height=540)

# %% [markdown]
# ### **Pandas Tutorial**

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('UB3DE5Bgfx4', width=960, height=540)

# %% [markdown]
# ### **Working with Dates and Time in Python**

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('mHezNgNBnuA', width=960, height=540)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('yZTBMMdPOww', width=960, height=540)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('TLdXM0A7SR8', width=960, height=540)

# %% [markdown]
# ### **Crash Course - Scikit-learn**

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('0B5eIE_1vpU', width=960, height=540)

# %% [markdown]
# ### **Machine Learning Crash Course**

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('hDKCxebp88A', width=960, height=540)
